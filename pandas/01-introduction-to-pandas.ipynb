# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 🐼 Introduction to Pandas
#
# Pandas is one of the most popular and powerful Python libraries for **data analysis and manipulation**.
# It provides easy-to-use data structures — mainly the **Series** and the **DataFrame** — which let you work with structured data efficiently.
#
# With Pandas, you can:
# - Load data from a wide range of sources (CSV, Excel, SQL, JSON, etc.)
# - Clean, filter, and transform datasets with simple commands
# - Perform statistical analysis and aggregations
# - Handle missing values and time series data
# - Visualize trends using built-in plotting or with Matplotlib/Seaborn
#
# In short, Pandas turns messy, raw data into a structured format that’s easy to explore, analyze, and visualize.
#
# Let’s start by importing Pandas and checking the version:
# ```python
# import pandas as pd
#
# print("Pandas version:", pd.__version__)

# %%
import pandas as pd

pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# # 🔧 Data Munging and Wrangling
#
# Before we can analyze data, we often need to **clean** and **reshape** it — this process is known as **data munging** or **data wrangling**.
#
# These two terms are often used interchangeably and refer to the process of:
# - **Collecting** raw data from different sources
# - **Cleaning** it by handling missing values, duplicates, or errors
# - **Transforming** it into a consistent and structured format
# - **Enriching** it by adding or merging useful information from other datasets
#
# In real-world projects, raw data is rarely ready for analysis. It might have:
# - Inconsistent column names or types
# - Missing or duplicate entries
# - Extra spaces, special characters, or incorrect values
#
# Pandas is especially powerful for data munging and wrangling tasks.
# It provides simple methods to:
# - Filter and sort data
# - Fill or drop missing values
# - Merge and join multiple datasets
# - Convert data types
# - Group and aggregate records
#
# ### Example:
# ```python
# import pandas as pd
#
# # Load a dataset
# df = pd.read_csv("data.csv")
#
# # Preview the first few rows
# df.head()
#
# # Drop missing values
# df_clean = df.dropna()
#
# # Convert a column to a consistent type
# df_clean["price"] = df_clean["price"].astype(float)
#
# # Check the cleaned data
# df_clean.info()
